# %%
from utils import fetch_lookup_df, normalize, create_solver_interpolators
from plotting import plot_T_vs_wCO2sys, plot_T_vs_wCO2solids

# %% [markdown]
# Create equilibrium plots for T vs mass frac. CO_2 in the system
