# %%
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
import pandas as pd
import numpy as np
from typing import Literal
from const import P

# %%
a = np.array((1, -2, 1.5, 1.9))

# %%
np.max(a)
# Out:
# np.float64(1.9)

# %%
np.amax(a)
# Out:
# np.float64(1.9)
